# %%
from ast import increment_lineno
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from numpy.random import randn

# %%
df = pd.DataFrame(randn(15,3),columns=['x','y','z'])
df
# Out:
#            x         y         z
# 0  -2.880253 -0.165064 -0.087772
# 1  -1.761309 -1.748906 -0.041818
# 2  -0.675676 -0.857340 -0.599773
# 3   0.654153  0.739491  1.726064
# 4   0.829460  0.656189  1.127513
# 5  -1.311033  0.386592  0.134184
# 6   0.402788  0.698310 -0.119406
# 7  -0.976202  0.013240 -0.196525
# 8  -1.473168  1.466895  0.752035
# 9   2.087831  0.333405 -0.135999
# 10  1.507750 -0.552745  0.257100
# 11  1.032338 -1.164485 -1.392299
# 12 -0.220210  1.247528 -0.466185
# 13 -0.477108 -1.317980  0.900722
# 14  1.146870 -0.396206  0.709387

# %%
# barplot
df.plot.bar()
plt.show()

# %%
df.plot(kind='bar')
# Out:
# <Axes: >

# %%
#horizontal bar plot
df.plot.barh()
# Out:
# <Axes: >

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.passengers.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
flights.passengers.plot(kind='hist',bins=35)
# Out:
# <Axes: ylabel='Frequency'>

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights.drop(['month'],axis=1)
# Out:
#      year  passengers
# 0    1949         112
# 1    1949         118
# 2    1949         132
# 3    1949         129
# 4    1949         121
# ..    ...         ...
# 139  1960         606
# 140  1960         508
# 141  1960         461
# 142  1960         390
# 143  1960         432
#
# [144 rows x 2 columns]

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights.hist(color='r',figsize=((10,4)),bins=20)
plt.show()
