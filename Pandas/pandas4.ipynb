# %% [markdown]
# # Dataframe Manipulation

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
matrix_data=np.matrix('22,66,140;25,62,152;42,72,148;35,68,160;30,62,125')
row_labels=['Mrugank','Abhinav','Ammar','Chiku','Avi']
column_headings=['Age','Height','Weight']

# %%
df = pd.DataFrame(data=matrix_data,index=row_labels,columns=column_headings)
print(df)
# Out:
#          Age  Height  Weight
# Mrugank   22      66     140
# Abhinav   25      62     152
# Ammar     42      72     148
# Chiku     35      68     160
# Avi       30      62     125

# %%
ht_wt==df[['Height','Weight']]
ht_wt
# Out:
#          Height  Weight
# Mrugank      66     140
# Abhinav      62     152
# Ammar        72     148
# Chiku        68     160
# Avi          62     125

# %%
age_wt = df[['Age','Weight']]
age_wt
# Out:
#          Age  Weight
# Mrugank   22     140
# Abhinav   25     152
# Ammar     42     148
# Chiku     35     160
# Avi       30     125

# %%
print('Age Data :','\n','-'*30)
print(df.Age)
print('-'*30)
print('Height Data :','\n','-'*30)
print(df.Height)
print('-'*30)
print('Weight Data :','\n','-'*30)
print(df.Weight)
# Out:
# Age Data :
#  ------------------------------
# Mrugank    22
# Abhinav    25
# Ammar      42
# Chiku      35
# Avi        30
# Name: Age, dtype: int64
# ------------------------------
# Height Data :
#  ------------------------------
# Mrugank    66
# Abhinav    62
# Ammar      72
# Chiku      68
# Avi        62
# Name: Height, dtype: int64
# ------------------------------
# Weight Data :
#  ------------------------------
# Mrugank    140
# Abhinav    152
# Ammar      148
# Chiku      160
# Avi        125
# Name: Weight, dtype: int64

# %%
df.loc['Ammar']
# Out:
# Age        42
# Height     72
# Weight    148
# Name: Ammar, dtype: int64

# %%
df.iloc[2]
# Out:
# Age        42
# Height     72
# Weight    148
# Name: Ammar, dtype: int64

# %%
df.loc[['Mrugank','Avi']]
# Out:
#          Age  Height  Weight
# Mrugank   22      66     140
# Avi       30      62     125

# %%
df.iloc[[0,4]]
# Out:
#          Age  Height  Weight
# Mrugank   22      66     140
# Avi       30      62     125

# %%
df.loc['Chiku',['Age','Height']]
# Out:
# Age       35
# Height    68
# Name: Chiku, dtype: int64

# %%
df.iloc[3,[0,2]]
# Out:
# Age        35
# Weight    160
# Name: Chiku, dtype: int64

# %% [markdown]
# ## select data on condition

# %%
print(df[df['Weight']>150])
# Out:
#          Age  Height  Weight
# Abhinav   25      62     152
# Chiku     35      68     160

# %%
demo1 =df['Weight']>145
demo2 =df['Height']>65

# %%
print('height>65 and weight>150','\n','-'*30)
print(df[demo1 & demo2])
# Out:
# height>65 and weight>150
#  ------------------------------
#        Age  Height  Weight
# Ammar   42      72     148
# Chiku   35      68     160

# %%
print('dataframe with age and weight columns where Height>65 :')
print(df[demo2][['Age','Weight']])
# Out:
# dataframe with age and weight columns where Height>65 :
#          Age  Weight
# Mrugank   22     140
# Ammar     42     148
# Chiku     35     160

# %%
new_df = df[demo2][['Age','Weight']]
new_df
# Out:
#          Age  Weight
# Mrugank   22     140
# Ammar     42     148
# Chiku     35     160

# %%
df
# Out:
#          Age  Height  Weight
# Mrugank   22      66     140
# Abhinav   25      62     152
# Ammar     42      72     148
# Chiku     35      68     160
# Avi       30      62     125

# %%
df.reset_index()
# Out:
#      index  Age  Height  Weight
# 0  Mrugank   22      66     140
# 1  Abhinav   25      62     152
# 2    Ammar   42      72     148
# 3    Chiku   35      68     160
# 4      Avi   30      62     125

# %%
print('Rows with height<65','\n')
less_ht = df[df['Height']<65]
less_ht
# Out:
# Rows with height<65
#          Age  Height  Weight
# Abhinav   25      62     152
# Avi       30      62     125

# %%
print(less_ht.reset_index(drop=True))
# Out:
#    Age  Height  Weight
# 0   25      62     152
# 1   30      62     125

# %%
less_ht['Sport']='Gaming Football'.split( )
less_ht
# Out:
#          Age  Height  Weight     Sport
# Abhinav   25      62     152    Gaming
# Avi       30      62     125  Football

# %%
print(less_ht.set_index('Sport'))
# Out:
#           Age  Height  Weight
# Sport
# Gaming     25      62     152
# Football   30      62     125
